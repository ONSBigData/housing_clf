# %% [markdown]
# ### step 1: imports (usual nlp: NLTK/gensim /spaCy) / machine learning : (sklearn)

# %%
import pandas as pd
from operator import itemgetter
import string
import numpy as np
from collections import Counter
from sklearn.metrics import accuracy_score,classification_report
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.corpus import stopwords as sw
from nltk.corpus import wordnet as wn

from sklearn.pipeline import FeatureUnion
from sklearn.pipeline import Pipeline

from nltk import wordpunct_tokenize
from nltk import WordNetLemmatizer
from nltk import sent_tokenize
from nltk import pos_tag
from nltk import bigrams
from nltk import word_tokenize

from sklearn.feature_extraction import DictVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import classification_report

from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.svm import SVC

from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import StandardScaler

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MaxAbsScaler 


from nltk.sentiment.util import mark_negation
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import Pipeline
from sklearn.svm import LinearSVC
from sklearn.base import TransformerMixin
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import SGDClassifier
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from tpot import TPOTClassifier


from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.neural_network import MLPClassifier
from sklearn.calibration import CalibratedClassifierCV
from sklearn.linear_model import LogisticRegressionCV
from gensim.models.doc2vec import TaggedDocument, Doc2Vec
from sklearn.preprocessing import Binarizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import log_loss

# %%
import spacy
spacy.load('en')

# %% [markdown]
# ### step 2: create a tokenizer that uses a regexp for tokens but also performs lemmatization if possible

# %%
import spacy
from nltk.corpus import stopwords
stop = stopwords.words('english')
import re
regexp = re.compile('(?u)\\b\\w\\w+\\b')

# load spacy language model and save old tokenizer
en_nlp = spacy.load('en')
old_tokenizer = en_nlp.tokenizer
# replace the tokenizer with the preceding regexp
en_nlp.tokenizer = lambda string: old_tokenizer.tokens_from_list(
    regexp.findall(string))

# create a custom tokenizer using the SpaCy document processing pipeline
# (now using our own tokenizer)
def custom_tokenizer(document):
    doc_spacy = en_nlp(document, entity=False, parse=False)
    return [token.lemma_ for token in doc_spacy]

# %% [markdown]
# ### Useful Functions
#
# #### a function to find a substring within a string. If found it outputs the position within the string.Otherwise -5000

# %%
def find_str(s, char):
    index = 0

    if char in s:
        c = char[0]
        for ch in s:
            if ch == c:
                if s[index:index+len(char)] == char:
                    return index

            index += 1

    return -5000

#test function
print(find_str("not only a development but also kind of a park home.","gorilla"))
print(find_str("not only python but scala and spark and monkeys","python"))
# Out:
# -5000
# 9

# %%
def truefalse_to_binary(input):

  

    if (input == 'True') or (input == 'T') or (input == 'TRUE'):
        output = 1
    else:
        output = 0


    return pd.Series(dict(output=output))

# %% [markdown]
# #### a function to output the most important features of a linear classifier.

# %%
def show_most_informative_features(model, text=None, n=15):
    """
    Accepts a Pipeline with a classifer and a TfidfVectorizer and computes
    the n most informative features of the model. If text is given, then will
    compute the most informative features for classifying that text.
    Note that this function will only work on linear models with coefs_
    """
    # Extract the vectorizer and the classifier from the pipeline
    vectorizer = model.named_steps['vectorizer']
    classifier = model.named_steps['classifier']

    # Check to make sure that we can perform this computation
    if not hasattr(classifier, 'coef_'):
        raise TypeError(
            "Cannot compute most informative features on {} model.".format(
                classifier.__class__.__name__
            )
        )

    if text is not None:
        # Compute the coefficients for the text
        tvec = model.transform([text]).toarray()
    else:
        # Otherwise simply use the coefficients
        tvec = classifier.coef_

    # Zip the feature names with the coefs and sort
    coefs = sorted(
        zip(tvec[0], vectorizer.get_feature_names()),
        key=itemgetter(0), reverse=True
    )

    topn  = zip(coefs[:n], coefs[:-(n+1):-1])

    # Create the output string to return
    output = []

    # If text, add the predicted value to the output.
    if text is not None:
        output.append("\"{}\"".format(text))
        output.append("Classified as: {}".format(model.predict([text])))
        output.append("")

    # Create two columns with most negative and most positive features.
    for (cp, fnp), (cn, fnn) in topn:
        output.append(
            "{:0.4f}{: >18}                {:0.4f}{: >18}".format(cp, fnp, cn, fnn)
        )

    return "\n".join(output)

# %% [markdown]
# #### a function to strip punctuation and stopwords out of a dataframe text column
# (needed sometimes for preprocessing)

# %%
def getstopwordsout(input):
    exclude = set(string.punctuation)
    output = ' '.join([word for word in input.split() if word not in (stopwords.words('english'))])
    
    output = ''.join(ch for ch in output if ch not in exclude)

    return pd.Series(dict(output=output))

# %% [markdown]
# ### Machine Learning scikit learn Estimator and Pipeline definitions

# %%
### ML Pipeline 1 : Countvectorizer / tfidf transformer / Logistic Regression Classifier

# %%
trigram_LR_clf = Pipeline([


    ('vectorizer', CountVectorizer(analyzer="word",
                                   ngram_range=(1, 3),
                                   tokenizer=custom_tokenizer,         
                                   max_features=10000)),

   
    ('transformer', TfidfTransformer()),  # tfidf weighting on Document/Text Matrix

    #('best', TruncatedSVD(n_components=200)),  # if we need dimensionality reduction 
    
    ('classifier', LogisticRegression())     # or any other classifier deemed useful!

   
])

# %%
### Handpicked features custom scikit learn extractor/Transformer 

#### length of text / number of sentences / existance of specific strings and position

# %%
class TextStats(BaseEstimator, TransformerMixin):
    """Extract features from each zoopla csv row for DictVectorizer"""

    def fit(self, x, y=None):
        return self

    def transform(self, zooplatext):
        return [{'length': len(text),
                 'num_sentences': text.count('.'),
                 'caravanindex':find_str(text,"caravan"),
                 'parkhomeindex':find_str(text,"park home"),
                 'bedroomparkhomeindex':find_str(text,"bedroom park home"),
                 'apartmentindex':find_str(text,"apartment"),
                 'flatindex':find_str(text,"flat"),
                 'holidayindex':find_str(text,"holiday"),
                 'challetindex':find_str(text,"challet"),
                 'statichomeindex':find_str(text,"static home"),
                 'staticcaravanindex':find_str(text,"static caravan"),
                 'mobilehomeindex':find_str(text,"mobile home"),
                 'parklodgeindex':find_str(text,"park lodge"),
                 'holidayindex':find_str(text,"holiday"),
                 'holidayvillageindex':find_str(text,"holiday village")
                }
                for text in zooplatext]

# %%
textstats = Pipeline([
             
                ('handpickedfeatures', TextStats()),  # returns a list of dicts
                ('vect', DictVectorizer()),  # list of dicts -> feature matrix
                ('classifier', LogisticRegression())     # or any other classifier deemed useful!
    
])

# %%
# TODO: explore
# different learning rate schedules and momentum parameters for the NN MLP classifier
params = [{'solver': 'sgd', 'learning_rate': 'constant', 'momentum': 0,
           'learning_rate_init': 0.2},
          {'solver': 'sgd', 'learning_rate': 'constant', 'momentum': .9,
           'nesterovs_momentum': False, 'learning_rate_init': 0.2},
          {'solver': 'sgd', 'learning_rate': 'constant', 'momentum': .9,
           'nesterovs_momentum': True, 'learning_rate_init': 0.2},
          {'solver': 'sgd', 'learning_rate': 'invscaling', 'momentum': 0,
           'learning_rate_init': 0.2},
          {'solver': 'sgd', 'learning_rate': 'invscaling', 'momentum': .9,
           'nesterovs_momentum': True, 'learning_rate_init': 0.2},
          {'solver': 'sgd', 'learning_rate': 'invscaling', 'momentum': .9,
           'nesterovs_momentum': False, 'learning_rate_init': 0.2},
          {'solver': 'adam', 'learning_rate_init': 0.01}]

labels = ["constant learning-rate", "constant with momentum",
          "constant with Nesterov's momentum",
          "inv-scaling learning-rate", "inv-scaling with momentum",
          "inv-scaling with Nesterov's momentum", "adam"]

# %%
trigram_NN_clf = Pipeline([


    ('vectorizer', CountVectorizer(analyzer="word",
                                   ngram_range=(1, 3),
                                   tokenizer=custom_tokenizer,        
                                   max_features=10000)),

    ('transformer', TfidfTransformer()),
    ('classifier', MLPClassifier(learning_rate_init=0.01,
                    hidden_layer_sizes=10, max_iter=100, activation='tanh', verbose=100,
                    early_stopping=True, validation_fraction=0.05, alpha=1e-10)) 
   

   
])

# %%
FeatUnion_clf = Pipeline([


    # Use FeatureUnion to combine the features from bag of words model and 
    # other ad hoc features such as text statistics and position of certain words
    
    
    ('union', FeatureUnion(
        
        
        
        transformer_list=[

           
            # 
            # Pipeline for standard bag-of-words model for body
            #
            
            ('text_bow_tfidf', Pipeline([
            ('vectorizer', CountVectorizer(analyzer="word",
                                   ngram_range=(1, 3),
                                   tokenizer=custom_tokenizer,         
                                   max_features=10000)),
            ('transformer', TfidfTransformer()),  # tfidf weighting on Document/Text Matrix
            #('best', TruncatedSVD(n_components=200)),  # if we need dimensionality reduction     
           
            ])),

            
            #
            # Pipeline for pulling ad hoc features from text
            #
            
            ('text_stats_features', Pipeline([
                ('handpickedfeatures', TextStats()),  # returns a list of dicts
                ('vect', DictVectorizer()),  # list of dicts -> feature matrix
            ])),

        ],

        # weight components in FeatureUnion
        transformer_weights={
           
            'text_bow_tfidf': 0.8,
            'text_stats_features': 0.5,
                             },
                                               )),

    
    
    ('classifier', LogisticRegression())     # or any other classifier deemed useful for the combined features!
    
    # like a SVC classifier on the combined features
    #('svc', SVC(kernel='linear')),
])

# %%
#load your dataframe here : expecting a text column and a label column.. change vars 


df=pd.read_csv('allproperties.csv',encoding='latin1')

# %%
#check the details of the dataframe

# %%
df.shape
# Out:
# (1334, 4)

# %%
df.query("label == 1").shape
# Out:
# (685, 4)

# %%
df.query("label == 0").shape
# Out:
# (649, 4)

# %%
df.head()
# Out:
#    Unnamed: 0  label holiday  \
# 0      183450      0     NaN
# 1      130340      0     NaN
# 2       69085      0     NaN
# 3       88547      0     NaN
# 4      111176      0     NaN
#
#                                                 text
# 0  ground floor lounge 584m192x340m112 well propo...
# 1   stunning 3 bedroom semi detached property  si...
# 2  tiger lettings pleased market rent large 5 bed...
# 3  available 4th december unfurnished excellent l...
# 4  superbly presented spacious grade ii listed 3 ...

# %% [markdown]
# ### read data in a way sklearn understands and split training / test data

# %%
#run only if needed (if you dont use current tokenizer/lemmatizer)


#df['text'] = df['description_lower'].apply(lambda x:  getstopwordsout(x)    )
#df['label'] = df['static'].apply(lambda x:truefalse_to_binary(x))

# %%
X=df['text'].values.astype('U')
y=df['label'].values

# %%
#split between training set and test set


train_X, test_X, train_y, test_y = train_test_split(X,y, test_size=0.2)

# %% [markdown]
# ### Fit/score/crossvalidate classifiers

# %%
#fit handpicked features clf

# %%
textstats.fit(train_X,train_y)
# Out:
# Pipeline(memory=None,
#      steps=[('handpickedfeatures', TextStats()), ('vect', DictVectorizer(dtype=<class 'numpy.float64'>, separator='=', sort=True,
#         sparse=True)), ('classifier', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False))])

# %%
### cross-validation scores for the handpicked-features classifier.

# %%
scores = cross_val_score(textstats, X, y, cv=5)

print("------------------- pipeline -----------------------")
print("vectorizer: ",textstats.named_steps['vect'])

print("classifier: ",textstats.named_steps['classifier'])



print (scores)
print (np.mean(scores))
# Out:
# ------------------- pipeline -----------------------
# vectorizer:  DictVectorizer(dtype=<class 'numpy.float64'>, separator='=', sort=True,
#         sparse=True)
# classifier:  LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)
# [ 0.97003745  0.98501873  0.92509363  0.97003745  0.81203008]
# 0.932443468221

# %%
Y_pred_prob = textstats.predict_proba(test_X)[:,1]
Y_pred = textstats.predict(test_X)


print('Handpicked features clasifier Log-loss = {:.5f}'.format(log_loss(test_y, Y_pred_prob,eps=1e-15)))
# Out:
# Handpicked features clasifier Log-loss = 0.15877

# %%
# run the following if there is need to output test,pred,pred_proba for the classifier

# %%
HPoutputdataframe = pd.DataFrame({'test_X':test_X,'Y_pred':Y_pred,'test_y':test_y,'Y_pred_prob':Y_pred_prob})
sout = HPoutputdataframe.sort_values(['Y_pred_prob', 'Y_pred'], ascending=[False, False])

# %%
sout.to_html("HPCLFtest.htm")

# %%
### cross-validation scores for the neural network classifier.

# %%
trigram_NN_clf.fit(train_X, train_y)
# Out:
# Iteration 1, loss = 0.52015621
# Validation score: 0.925926
# Iteration 2, loss = 0.24803634
# Validation score: 0.925926
# Iteration 3, loss = 0.15620580
# Validation score: 0.925926
# Iteration 4, loss = 0.11362953
# Validation score: 0.925926
# Validation score did not improve more than tol=0.000100 for two consecutive epochs. Stopping.
# Pipeline(memory=None,
#      steps=[('vectorizer', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=10000, min_df=1,
#         ngram_range=(1, 3), preprocessor=None, stop_words=None,
#       ...e=True, solver='adam', tol=0.0001, validation_fraction=0.05,
#        verbose=100, warm_start=False))])

# %%
scores = cross_val_score(trigram_NN_clf, X, y, cv=5)
# Out:
# Iteration 1, loss = 0.56841474
# Validation score: 0.870370
# Iteration 2, loss = 0.28895703
# Validation score: 0.925926
# Iteration 3, loss = 0.18123014
# Validation score: 0.907407
# Iteration 4, loss = 0.13332840
# Validation score: 0.907407
# Iteration 5, loss = 0.10450689
# Validation score: 0.925926
# Validation score did not improve more than tol=0.000100 for two consecutive epochs. Stopping.
# Iteration 1, loss = 0.55155297
# Validation score: 0.925926
# Iteration 2, loss = 0.27811731
# Validation score: 0.925926
# Iteration 3, loss = 0.17944675
# Validation score: 0.925926
# Iteration 4, loss = 0.13216707
# Validation score: 0.944444
# Iteration 5, loss = 0.10401947
# Validation score: 0.944444
# Iteration 6, loss = 0.08963902
# Validation score: 0.944444
# Iteration 7, loss = 0.07758243
# Validation score: 0.944444
# Validation score did not improve more than tol=0.000100 for two consecutive epochs. Stopping.
# Iteration 1, loss = 0.55353668
# Validation score: 0.870370
# Iteration 2, loss = 0.27263961
# Validation score: 0.907407
# Iteration 3, loss = 0.16629942
# Validation score: 0.944444
# Iteration 4, loss = 0.11387040
# Validation score: 0.962963
# Iteration 5, loss = 0.08515284
# Validation score: 0.962963
# Iteration 6, loss = 0.06815882
# Validation score: 0.962963
# Iteration 7, loss = 0.05856938
# Validation score: 0.962963
# Validation score did not improve more than tol=0.000100 for two consecutive epochs. Stopping.
# Iteration 1, loss = 0.59337767
# Validation score: 0.851852
# Iteration 2, loss = 0.35326492
# Validation score: 0.833333
# Iteration 3, loss = 0.23302041
# Validation score: 0.870370
# Iteration 4, loss = 0.17633401
# Validation score: 0.870370
# Iteration 5, loss = 0.14019869
# Validation score: 0.870370
# Iteration 6, loss = 0.11497183
# Validation score: 0.851852
# Validation score did not improve more than tol=0.000100 for two consecutive epochs. Stopping.
# Iteration 1, loss = 0.58572652
# Validation score: 0.888889
# Iteration 2, loss = 0.34429316
# Validation score: 0.888889
# Iteration 3, loss = 0.21265484
# Validation score: 0.888889
# Iteration 4, loss = 0.13705858
# Validation score: 0.888889
# Validation score did not improve more than tol=0.000100 for two consecutive epochs. Stopping.

# %%
print (scores)
print (np.mean(scores))
# Out:
# [ 0.92883895  0.95505618  0.8576779   0.97378277  0.80827068]
# 0.904725296387

# %%
Y_pred_prob = trigram_NN_clf.predict_proba(test_X)[:,1]
Y_pred = trigram_NN_clf.predict(test_X)

print('NN perceptron classifier  Log-loss = {:.5f}'.format(log_loss(test_y, Y_pred_prob)))
# Out:
# NN perceptron classifier  Log-loss = 0.34971

# %%
#output text / prediction / prediction probability in a dataframe!

NNoutputdataframe = pd.DataFrame({'test_X':test_X,'Y_pred':Y_pred,'test_y':test_y,'Y_pred_prob':Y_pred_prob})
sout = NNoutputdataframe.sort_values(['Y_pred_prob', 'Y_pred'], ascending=[False, False])

# %%
sout.to_html("NNCLFtest.htm")

# %%
# Logistic Regression classifier fit/score/cv

# %%
print(trigram_LR_clf.fit(train_X, train_y))
# Out:
# Pipeline(memory=None,
#      steps=[('vectorizer', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=10000, min_df=1,
#         ngram_range=(1, 3), preprocessor=None, stop_words=None,
#       ...ty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False))])

# %%
print(trigram_LR_clf.score(test_X, test_y))
# Out:
# 0.940074906367

# %%
### cross-validation scores for the Logistic Regression classifier.

# %%
# 5-fold crossvalidation

scores = cross_val_score(trigram_LR_clf, X, y, cv=5)

print("------------------- pipeline -----------------------")
print("vectorizer: ",trigram_LR_clf.named_steps['vectorizer'])
#print("transformer: ",bigram_clf.named_steps['transformer'])
print("classifier: ",trigram_LR_clf.named_steps['classifier'])
print (scores)
print (np.mean(scores))
# Out:
# ------------------- pipeline -----------------------
# vectorizer:  CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=10000, min_df=1,
#         ngram_range=(1, 3), preprocessor=None, stop_words=None,
#         strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#         tokenizer=<function custom_tokenizer at 0x7f318c5df400>,
#         vocabulary=None)
# classifier:  LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)
# [ 0.94007491  0.95131086  0.85393258  0.98501873  0.86090226]
# 0.918247866858

# %%
Y_pred_prob = trigram_LR_clf.predict_proba(test_X)[:,1]
Y_pred = trigram_LR_clf.predict(test_X)

print('logistic regression classifier  Log-loss = {:.5f}'.format(log_loss(test_y, Y_pred_prob)))
# Out:
# logistic regression classifier  Log-loss = 0.26580

# %%
# run the following if there is need to output test,pred,pred_proba for the classifier

# %%
LRoutputdataframe = pd.DataFrame({'test_X':test_X,'Y_pred':Y_pred,'test_y':test_y,'Y_pred_prob':Y_pred_prob})
sout = LRoutputdataframe.sort_values(['Y_pred_prob', 'Y_pred'], ascending=[False, False])

# %%
sout.to_html("LRCLFtest.htm")

# %%
print(show_most_informative_features(trigram_LR_clf))
# Out:
# 3.7706              park                -2.3824             floor
# 2.9684              home                -1.4970         apartment
# 2.9149         park home                -1.3791             first
# 1.9782              side                -1.2853             house
# 1.3939           holiday                -1.2115       first floor
# 1.3104            aspect                -1.2073              rear
# 1.2457       window side                -1.2070              face
# 1.1733      bedroom park                -1.0302              flat
# 1.1473 bedroom park home                -1.0177             three
# 1.0361 glaze window side                -0.9364central heating radiator
# 1.0288          wardrobe                -0.9001  heating radiator
# 1.0093      home situate                -0.8876         available
# 0.9772 park home situate                -0.8348     three bedroom
# 0.9519       side aspect                -0.8263             acces
# 0.9128      holiday home                -0.8158         reception

# %% [markdown]
# ##  FEATURE UNION CLASSIFIER fit/score/crossvalidate

# %%
FeatUnion_clf.fit(train_X,train_y)
# Out:
# Pipeline(memory=None,
#      steps=[('union', FeatureUnion(n_jobs=1,
#        transformer_list=[('text_bow_tfidf', Pipeline(memory=None,
#      steps=[('vectorizer', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, m...ty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False))])

# %%
print(FeatUnion_clf.score(test_X, test_y))
# Out:
# 0.932584269663

# %%
# 5-fold crossvalidation

scores = cross_val_score(FeatUnion_clf, X, y, cv=5)

print("-----------------feature union (BOW + ad hoc) pipeline -----------------------")

print (scores)
print (np.mean(scores))
# Out:
# -----------------feature union (BOW + ad hoc) pipeline -----------------------
# [ 0.97003745  0.98501873  0.8988764   0.97003745  0.81203008]
# 0.927200022528

# %%
Y_pred_prob = FeatUnion_clf.predict_proba(test_X)[:,1]
Y_pred = FeatUnion_clf.predict(test_X)

print('Feature Union classifier  Log-loss = {:.5f}'.format(log_loss(test_y, Y_pred_prob)))
# Out:
# Feature Union classifier  Log-loss = 0.15744

# %%
FUoutputdataframe = pd.DataFrame({'test_X':test_X,'Y_pred':Y_pred,'test_y':test_y,'Y_pred_prob':Y_pred_prob})
sout = FUoutputdataframe.sort_values(['Y_pred_prob', 'Y_pred'], ascending=[False, False])
sout.to_html("FU_CLFtest.htm")

# %%
#EVALUATION PHASE

# SK Learn classification report and ROC curve for the classifier

# %%
from sklearn import metrics
from sklearn.metrics import roc_curve, auc,brier_score_loss
from ggplot import *

preds = trigram_LR_clf.predict_proba(test_X)[:,1]
fpr, tpr, _ = metrics.roc_curve(test_y, preds)



df = pd.DataFrame(dict(fpr=fpr, tpr=tpr))
#ggplot(df, aes(x='fpr', y='tpr')) +\
#    geom_line() + \
#    geom_abline(linetype='dashed')
    
auc = metrics.auc(fpr,tpr)
prob_pos = trigram_LR_clf.predict_proba(test_X)[:, 1]
br=brier_score_loss(test_y, prob_pos)
print("Area under Curve: ",auc,"   Brier Score (the lower the better) ",br)
# Out:
# /home/mamonu/anaconda3/lib/python3.6/site-packages/ggplot/utils.py:81: FutureWarning: pandas.tslib is deprecated and will be removed in a future version.
# You can access Timestamp as pandas.Timestamp
#   pd.tslib.Timestamp,
# /home/mamonu/anaconda3/lib/python3.6/site-packages/ggplot/stats/smoothers.py:4: FutureWarning: The pandas.lib module is deprecated and will be removed in a future version. These are private functions and can be accessed from pandas._libs.lib instead
#   from pandas.lib import Timestamp
# /home/mamonu/anaconda3/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# Area under Curve:  0.989498644986    Brier Score (the lower the better)  0.0608650957972

# %%
ggplot(df, aes(x='fpr', y='tpr')) +\
    geom_line() + \
    geom_abline(linetype='dashed')
# Out:
# <ggplot: (-9223363306156201016)>

# %%
import matplotlib.pyplot as plt
from sklearn.calibration import calibration_curve
# %matplotlib inline 

plt.figure(figsize=(10, 10))
ax1 = plt.subplot2grid((3, 1), (0, 0), rowspan=2)
ax2 = plt.subplot2grid((3, 1), (2, 0))

ax1.plot([0, 1], [0, 1], "k:", label="Perfectly calibrated")
for clf, name in [(trigram_LR_clf, 'LR trigram'),(FeatUnion_clf, 'Feature Union and LR ')]:
    clf.fit(train_X, train_y)
    if hasattr(clf, "predict_proba"):
        prob_pos = clf.predict_proba(test_X)[:, 1]
    else:  # use decision function
        prob_pos = clf.decision_function(test_X)
        prob_pos = \
            (prob_pos - prob_pos.min()) / (prob_pos.max() - prob_pos.min())
    fraction_of_positives, mean_predicted_value = \
        calibration_curve(test_y, prob_pos, n_bins=10)

    ax1.plot(mean_predicted_value, fraction_of_positives, "s-",
             label="%s" % (name, ))

    ax2.hist(prob_pos, range=(0, 1), bins=20, label=name,
             histtype="step", lw=2)

ax1.set_ylabel("Fraction of positives")
ax1.set_ylim([-0.05, 1.05])
ax1.legend(loc="lower right")
ax1.set_title('Calibration plots  (reliability curve)')

ax2.set_xlabel("Mean predicted value")
ax2.set_ylabel("Count")
ax2.legend(loc="upper center", ncol=2)

plt.tight_layout()
plt.show()

# %% [markdown]
# ** Predict labels from UDBC data

# %%
# caravan_A.csv contains a sample of data from the UDBC Zoopla dataset that we are going to use our classifier to 
# predict whether its a caravan or not.

newdf=pd.read_csv('caravan_A.csv',encoding='latin1')

# %%
udbc_X=newdf['description'].values.astype('U')

# %%
Y_pred = FeatUnion_clf.predict(udbc_X)
Y_pred_prob = FeatUnion_clf.predict_proba(udbc_X)[:,1]
#print('Feature Union classifier  Log-loss = {:.5f}'.format(log_loss(test_y, Y_pred_prob)))
Pred_output_dataframe = pd.DataFrame({'udbc_X':udbc_X,'Y_pred':Y_pred,'Y_pred_prob':Y_pred_prob})

# %%
Pred_output_dataframe.head()
pd.set_option('display.max_colwidth', -1)

#Sorted predictions
spreds=Pred_output_dataframe.sort_values(['Y_pred_prob', 'Y_pred'], ascending=[False, False])

# %%
# Out:
#      Y_pred  Y_pred_prob  \
# 443  1       0.989614
# 411  1       0.989605
# 210  1       0.989600
# 400  1       0.989584
# 330  1       0.989571
# 371  1       0.989531
# 307  1       0.989496
# 444  1       0.989406
# 445  1       0.989406
# 379  1       0.989318
# 331  1       0.989302
# 288  1       0.989248
# 204  1       0.989183
# 384  1       0.989154
# 340  1       0.989150
# 392  1       0.989112
# 418  1       0.989050
# 162  1       0.988932
# 186  1       0.988931
# 377  1       0.988920
# 295  1       0.988895
# 442  1       0.988783
# 327  1       0.988780
# 187  1       0.988718
# 450  1       0.988650
# 235  1       0.988639
# 419  1       0.988574
# 452  1       0.988177
# 358  1       0.988000
# 380  1       0.987987
# ..  ..            ...
# 90   0       0.499624
# 141  0       0.473442
# 59   0       0.470540
# 414  0       0.470172
# 131  0       0.468151
# 352  0       0.467032
# 136  0       0.460606
# 135  0       0.457771
# 144  0       0.453470
# 279  0       0.453277
# 97   0       0.448873
# 254  0       0.442969
# 255  0       0.442969
# 274  0       0.442525
# 130  0       0.441625
# 252  0       0.435562
# 36   0       0.431744
# 37   0       0.431744
# 112  0       0.431691
# 61   0       0.428067
# 319  0       0.426963
# 323  0       0.426473
# 329  0       0.426451
# 66   0       0.422099
# 169  0       0.421374
# 170  0       0.420830
# 108  0       0.418360
# 109  0       0.418360
# 86   0       0.408549
# 425  0       0.400363
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 443  a detached park home bungalow with secluded garden, backing onto fields and offered for sale with no chain. the property is located on this highly sought after residential park set in prime kentish countryside. the accommodation comprises three bedrooms, bathroom, lounge/diner and kitchen. the property requires some redecoration which is reflected in the highly competitive asking price.maintenance: Â£134 per month. to be confirmed by the vendor's solicitor. lounge/diner: 6.02m x 4.14m single glazed entrance door. double aspect windows. serving hatch to kitchen. kitchen: 3.38m x 2.95m range of cupboards and drawers with work surface over. stainless steel sink unit and drainer. wall mounted dimplex heater. externally: secluded gardens to side and rear and backing onto fields. garden shed. parking space. bedroom two: 3.18m x 2.95m window to rear. dimplex heater. sink unit. bedroom three: 2.34m x 1.93m window to side. bedroom one: 3.7m x 3m to wardrobes. window to side. built in wardrobes. bathroom: suite comprising panel bath with electric shower over, pedestal wash hand basin and low level wc. built in cupboard.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ...
# 411  built in 2004 this detached park home is a credit to the present owners. they have decorated throughout to a very high standard. the lounge is bright and airy, the kitchen/diner is a space that lends itself to entertaining family & friends. with two bedrooms, bathroom and en-suite cloakroom you will be wondering how all this can possibly fit inside. outside is off road parking for two cars and a small garden area with a paved patio.woodchurch has been voted 'best kent village' for a number of years with a post office, butchers, store, primary school and garage. the pubs are excellent with eating facilities.room sizes:ground floorlounge 19'10 Ã 11'10 (6.05m Ã 3.61m)kitchen/diner 19' Ã 11'10 (5.8m Ã 3.61m)bedroom 1 11'4 Ã 9'6 (3.46m Ã 2.9m)bedroom 2 9' Ã 9' (2.75m Ã 2.75m)outsidepaved patioparking for 2 carsthe information provided about this property does not constitute or form part of an offer or contract, nor may be it be regarded as representations. all interested parties must verify accuracy and your solicitor must verify tenure/lease information, fixtures & fittings and, where the property has been extended/converted, planning/building regulation consents. all dimensions are approximate and quoted for guidance only as are floor plans which are not to scale and their accuracy cannot be confirmed. reference to appliances and/or services does not imply that they are necessarily in working order or fit for the purpose.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 210  two bedroom vacant park home sited on a peaceful plot on the outskirts of charing near ashford.benefits include fitted kitchen and two en-suites to the bedrooms, an ideal retirement property.lounge: 5.84m x 3.53m double aspect double glazed windows to side and front. feature fireplace with inset gas fire. two radiators. six wall light fittings. kitchen: 4.04m x 2.82m glazed entrance door to side. fitted kitchen comprising single drainer stainless steel sink unit with cupboards under. space for washing machine. wide range of wall and base units with laminate work surfaces. door to hallway. hallway: open plan to dining room. garden: to side with fence surround. garage: to side, driveway leading to garage with up and over door. en-suite: pedestal wash hand basin. low level w.c. radiator. electric shaving point. en-suite: comprising shower cubicle with electric shower over. suspended wash hand basin. low level w.c. radiator. dining room: 2.87m x 2.57m double glazed window and door to side. radiator. archway to lounge. bedroom 2: 3.28m x 2.31m double glazed window to rear. built-in wardrobe. radiator. door to en-suite. bedroom 1: 3.28m x 2.31m double glazed window to rear. range of built-in wardrobes. door to en-suite.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ...
# 400  summarylocated just outside the popular village of woodchurch is this fantastic three bedroom park home. being only six years old, the home itself comes with the modern touches you'd expect today including a master ensuite bathroom with walk-in wardrobe and modern fully fitted kitchen/utility!descriptionif your entering your retirement years and are looking for a low maintenance home to set down your roots the look no further. situated just outside the popular village of woodchurch is shirkoak park, a park home site for the over 55s. just outside the park is a bus stop with regular services running to the local towns of ashford & tenterden. woodchurch itself has an array of shops and pubs if you fancy a stroll into the village. being just six years old this property is ideal for someone who wants easy living, you could just move straight in and continue enjoying life without the need for refurbishment. the property offers a fantastic flow with a double aspect lounge, dining area, modern fully fitted kitchen, utility room, master bedroom with ensuite bathroom and walk-in wardrobe, two further bedrooms, another walk-in wardrobe off the hallway and family bathroom. further the property also has the added benefit of driveway parking for two vehicles and a separate garage. the current vendors have added decking to the front of the property to give somewhere to sit outside and enjoy the view across the fields. call the team on for further details or to arrange your internal inspection!lounge 19' 4" x 11' 11" ( 5.89m x 3.63m )double glazed door to front, double glazed window to side, double glazed french doors to front, electric fire place with surround, telephone & tv point, two radiators and laminate flooring. open to dining area and hallway.dining room 7' 2" x 9' 4" ( 2.18m x 2.84m )double glazed window to side and laminate flooring. open to lounge area. door to kitchen.kitchen 7' 1" x 12' 6" ( 2.16m x 3.81m )fitted kitchen comprising matching wall and base units with work surfaces over, one and half bowl stainless steel sink/drainer, gas cooker point with suitable space for rangemaster and cooker hood extractor above, integrated dishwasher, integrated fridge/freezer, central heating boiler, pantry cupboard and vinyl flooring. double glazed window to rear. doorway to utility room. door to hallway. door to dining area.utility room 7' 10" x 5' 9" ( 2.39m x 1.75m )double glazed door to rear, matching wall and base units with work surfaces over, storage cupboard, plumbing for washing machine, radiator and vinyl flooring. doorway to kitchen.hallwayleading from lounge, doors to all bedrooms, door to bathroom, door to walk-in wardrobe with radiator, storage cupboards and loft access.bedroom one 9' 4" x 10' 9" ( 2.84m x 3.28m )double glazed window to rear, walk-in wardrobe and radiator. door to ensuite bathroom.en-suitedouble glazed window to side, bath/ mixer with shower over, wash hand basin with vanity, wc, extractor fan, radiator, shaver point, partly tiled walls and vinyl flooring.bedroom two 9' 4" x 12' 5" ( 2.84m x 3.78m )double glazed window to front, double fitted wardrobes, radiator and laminate flooring.bedroom three 6' 9" x 6' 4" ( 2.06m x 1.93m )double glazed window to front, fitted wardrobe, radiator and laminate flooring.bathroomdouble glazed window to front, bath/mixer with shower over, wash hand basin, wc, extractor fan, radiator, tiled walls and vinyl flooring.externallyparkingdriveway for two vehicles and garage. the garage currently has a single door so would need an up/over door fitted for parking vehicles in.gardenthe vendors have added decking to the front which gives a great space to sit outside and enjoy the view. there is also an other area to the side of the property which would be fantastic for planting up or growing vegetables.1. money laundering regulations - intending purchasers will be asked to produce identification documentation at a later stage and we would ask for your co-operation in order that th ...
# 330  guide price 80,000 - 100,000. located on the outskirts of woodchurch village is this exceptionally spacious detached park home. situated on a private residential park for the over 55's. the property comprises of three bedrooms, kitchen/diner, separate lounge, shower room, gardens and parking for approximately three cars. the property is situated in a convenient location on the edge of the sought after village of woodchurch which offers village shop, post office, butchers, inns, church and primary school together with a quint essential village green and windmill. for further information or to arrange a viewing contact selling agents on .entranceopaque double glazed window and door to:-hallwayradiator, door to accommodation, airing cupboard.lounge19' 3" x 11' 0"  (5.87m x 3.35m) double glazed opaque door to side, double glazed windows to two sides, radiator.kitchen / dining room15' 8" x 8' 2"  (4.78m x 2.49m) inclusive of units. double glazed window and double glazed boxed window to side, range of wall and base level units, stainless steel sink unit with mixer tap, stainless steel oven and hob, plumbing for washing machine, space for fridge/freezer, wall mounted boiler, radiator.bedroom 19' 0" x 7' 7"  (2.74m x 2.31m) double glazed window to rear, built-in wardrobe and cupboard, radiator.bedroom 29' 0" x 6' 5"  (2.74m x 1.96m) double glazed window to side, built-in wardrobe and cupboard, radiator.bedroom 39' 6" x 6' 9"  (2.9m x 2.06m) double glazed window to side, built-in storage cupboard, radiator.shower room/wcdouble glazed opaque window to side, corner shower cubicle, bidet, vanity enclosed wash hand basin, radiator, shaver point.externalgardensgardens to three sides of the home with patio areas, shrub and flower borders.parkingparking for approximately three cars to the side and front.important note to purchasers:we endeavour to make our sales particulars accurate and reliable, however, they do not constitute or form part of an offer or any contract and none is to be relied upon as statements of representation or fact. any services, systems and appliances listed in this specification have not been tested by us and no guarantee as to their operating ability or efficiency is given. all measurements have been taken as a guide to prospective buyers only, and are not precise. please be advised that some of the particulars may be awaiting vendor approval. if you require clarification or further information on any points, please contact us, especially if you are travelling some distance to view. fixtures and fittings other than those mentioned are to be agreed with the seller.guide price Â£80000 - Â£100000three bedroomspark homefitted wardrobes to bedroomskitchen dining roomdouble glazing where statedgas central heating systemdriveway parkingover 55s development                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ...
# 371  a superbly presented detached bungalow on this residential park home site in a lovely rural setting bordering a conservation area of woodland. the property offers two bedrooms, 16ft lounge plus a dining area off - in addition to a 15ft fitted kitchen, refitted only two years ago. there is double glazing, gas fired central heating and outside there are secluded gardens to the rear backing onto woodland. a further feature are the three parking spaces located to the front of the property. all in all a delightful retirement bungalow in an idyllic setting.service charge/pitch hire: currently Â£135.00 per calendar month to include pitch hire, water and sewerage. rear lobby/utility: door to side of property. lounge: 4.93m x 3.35m bay window to side. feature fire surround and gas coal effect fire. double glazed doors to verandah. through to:- lease: pitch hire agreement with park management. kitchen: 4.57m x 2.9m range of attractive modern units (renewed approximately two years ago). stainless steel sink and drainer sink unit. work surfaces to three walls. fitted hob, oven and extractor. cupboard housing "valliant" gas fired combi boiler for central heating and hot water. garden: lovely rear garden with mature trees and shrubs for seclusion. decked verandah. pedestrian side access (gated). additional area beyond garden with shed and greenhouse/store room. outside tap. parking to front for three vehicles. entrance hall: entrance door. laminate flooring. radiator. en-suite shower room: shower cubicle. low level wc. pedestal wash hand basin. radiator. dining room: 2.6m x 2.51m laminate flooring. window to rear. bedroom two: 3.4m x 2.9m range of built-in wardrobes to one wall. bay window to side. bedroom one: 2.9m x 2.9m window to side. doors to walk-in wardrobe and:- bathroom/wc: suite comprising panelled bath. wash hand basin set in vanity unit. low level wc.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ...
# 307  an extremely well presented two bedroom detached park home set in the yew tree development which is situated on the outskirts of charing village. the accommodation comprises kitchen, living/dining room, two bedrooms and a shower room. the property benefits from double glazing and central heating. to the side of the property there is parking for approximately two vehicles with garden area to the front, rear and other side. charing village offers a wide range of amenities including a variety of shops, pubs, restaurants, library, school, mainline rail station and easy access to the motorway network for ashford, canterbury and maidstone. early internal viewing of this property is highly recommended.double glazed front door leading to;kitchen 10' 11" x 9' 7" (3.33m x 2.92m) double glazed window to side, fitted with a range of wall and base units, 1 1/2 bowl sink and drainer with mixer tap, fitted dishwasher, double electric oven, electric hob with extractor over, fitted fridge freezer, tile effect floor, radiator.hallway storage cupboard.living/dining room 19' 8" x 10' 11" (5.99m x 3.33m) two double glazed bow windows to front and double glazed patio doors to side, two radiators, fire surround.bedroom one 12' 4" x 9' 7" (3.76m x 2.92m) double glazed window to rear and side, radiator, fitted with a range of bedroom furniture.bedroom two 9' 7" x 9' 3" (2.92m x 2.82m) double glazed window to rear, radiator, fitted with a range of bedroom furniture.shower room double glazed window to side, shower cubicle with shower over, close couple w/c, wash hand basin mounted on wood base, heated towel rail, tile effect floor.airing cupboard wall mounted boiler.external garden area to front side and rear to the property with parking for approximately two vehicles.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 444  a detached park home bungalow with secluded garden, backing onto fields and offered for sale with no chain. the property is located on this highly sought after residential park set in prime kentish countryside. the accommodation comprises three bedrooms, bathroom, lounge/diner and kitchen. the property requires some redecoration which is reflected in the highly competitive asking price.three bedroom detached bungalowsought after residential park locationsecluded gardens & backing onto fieldsno chainlounge/diner:19'9" x 13'7" (6.02m x 4.14m). single glazed entrance door. double aspect windows. serving hatch to kitchen.kitchen:11'1" x 9'8" (3.38m x 2.95m). range of cupboards and drawers with work surface over. stainless steel sink unit and drainer. wall mounted dimplex heater.bathroom: suite comprising panel bath with electric shower over, pedestal wash hand basin and low level wc. built in cupboard.bedroom one:12'2" (3.7m) x 9'10" (3m) to wardrobes.. window to side. built in wardrobes.bedroom three:7'8" x 6'4" (2.34m x 1.93m). window to side.bedroom two:10'5" x 9'8" (3.18m x 2.95m). window to rear. dimplex heater. sink unit.externally: secluded gardens to side and rear and backing onto fields. garden shed. parking space.maintenance: Â£134 per month. to be confirmed by the vendor's solicitor.3 bedrooms                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ...
# 445  a detached park home bungalow with secluded garden, backing onto fields and offered for sale with no chain. the property is located on this highly sought after residential park set in prime kentish countryside. the accommodation comprises three bedrooms, bathroom, lounge/diner and kitchen. the property requires some redecoration which is reflected in the highly competitive asking price.three bedroom detached bungalowsought after residential park locationsecluded gardens & backing onto fieldsno chainlounge/diner:19'9" x 13'7" (6.02m x 4.14m). single glazed entrance door. double aspect windows. serving hatch to kitchen.kitchen:11'1" x 9'8" (3.38m x 2.95m). range of cupboards and drawers with work surface over. stainless steel sink unit and drainer. wall mounted dimplex heater.bathroom: suite comprising panel bath with electric shower over, pedestal wash hand basin and low level wc. built in cupboard.bedroom one:12'2" (3.7m) x 9'10" (3m) to wardrobes.. window to side. built in wardrobes.bedroom three:7'8" x 6'4" (2.34m x 1.93m). window to side.bedroom two:10'5" x 9'8" (3.18m x 2.95m). window to rear. dimplex heater. sink unit.externally: secluded gardens to side and rear and backing onto fields. garden shed. parking space.maintenance: Â£134 per month. to be confirmed by the vendor's solicitor.3 bedrooms                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ...
# 379  located on an exclusive over 55's development, just outside woodchurch. your move are proud to offer this well presented residential park home. we encourage viewing at your earliest opportunity. accommodation comprises kitchen/dining room, lounge, inner hallway, two bedrooms and bathroom. externally there are gardens to the side and rear of the property plus a driveway for off road parking. in addition the property features gas central heating and double glazing where stated. the overall presentation of the home is well presented, so contact the office to arrange your appointment to view as soon as possible.kitchen/dining room16' 2" x 8' 1"  (4.93m x 2.46m) including units. the main entrance to the property is via a frosted double glazed door opening to kitchen/dining room. frosted double glazed door to side. fitted kitchen comprising range of beech veneer wall and base units with granite effect work surfaces. incorporating stainless steel sink and drainer. integral dishwasher. integral oven and hob with splashback and extractor hood over. space and plumbing for washing machine.lounge21' 3" x 11' 0"  (6.48m x 3.35m) textured and coved ceiling. two double glazed windows to rear. double glazed french doors opening to the side and onto the garden. radiator. t.v.point.hallwaybuilt in airing cupboard. doors giving access to:bedroom one14' 0" x 9' 4"  (4.27m x 2.84m) double glazed windows to side and rear. radiator. range of fitted bedroom furniture including two double wardrobes, chest of drawers and overhead cupboards.bedroom two9' 4" x 9' 0"  (2.84m x 2.74m) double glazed window to rear. radiator.bathroomfrosted double glazed window to side. three piece white bathroom suite comprising pedestal wash hand basin. close coupled w.c. panelled bath with mixer tap and shower attachment. radiator. part tiled walls. extractor fan.externalgardento the side there is a shingle area with steps leading up to front entrance door. open plan to rear garden. raised paved patio area with access to lounge. mainly laid to shaped lawn. flower borders to all boundaries. fence enclosed to three aspects.parkingto the opposite aspect to the main entrance. mainly laid to shingle. mature trees incorporated.important note to purchasers:we endeavour to make our sales particulars accurate and reliable, however, they do not constitute or form part of an offer or any contract and none is to be relied upon as statements of representation or fact. any services, systems and appliances listed in this specification have not been tested by us and no guarantee as to their operating ability or efficiency is given. all measurements have been taken as a guide to prospective buyers only, and are not precise. please be advised that some of the particulars may be awaiting vendor approval. if you require clarification or further information on any points, please contact us, especially if you are travelling some distance to view. fixtures and fittings other than those mentioned are to be agreed with the seller.excellent residential park homewith two double bedroomsintegrated appliances to kitchendriveway for off road parkingdouble glazing where statedgas fired central heatingexclusive over 55s developmentpopular woodchurch locationbus stop outside development entrance                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# ...
# 109  descriptionthis property is located approximately half a mile from the rural village of mydroilyn which benefits from a primary school and a public house. the village of llanarth, located approximately 3 miles away, has a shop, post office, garage, pub and primary school. a wider range of amenities is available around 6 miles away in the georgian town of aberaeron.accommodationentrance via timber door into:dining room 4.37m(14'4'') x 3.99m(13'1'')with window to fore, character exposed stone fireplace with wood-burner in situ on a slate hearth, exposed floor boards, exposed beams, open staircase to first floor.sitting room 5.08m(16'8'') x 3.91m(12'10'')with exposed timber floor boards, beamed ceiling, character stone fireplace with cast iron wood-burner effect oil-fired stove in situ, window to fore.kitchen / breakfast room 6.96m(22'10'') x 2.24m(7'4'')with attractive tiled flooring, exposed ceiling beams, oil-fired rayburn serving the central heating, belfast sink, under-stairs storage cupboard, door to:shower roomwith obscure-glazed window to side, low level flush wc, wash hand basin, shower cubicle.conservatoryaccessed from the kitchen via a stable-style door, with upvc double-glazed panels around, polycarbonate roofing, door out to rear garden, door to:utility areawith space and plumbing for washing machine and space/vent for tumble dryer.first flooraccessed via staircase in dining room to:landing areawith doors off to all first floor accommodation including:bedroom 1 4.11m(13'6'') x 3.84m(12'7'')with window to fore.bedroom 2 4.60m(15'1'') x 3.02m(9'11'')with window to fore.bedroom 3 3.53m(11'7'') x 2.82m(9'3'')with built-in airing cupboard.bedroom 4 2.95m(9'8'') x 2.24m(7'4'')currently used as a study, with window to rear.bathroomwith window to fore, roll-top bath, low level flush wc, wash hand basin, heated towel rail.rose cottagedivided partitioned into individual rooms, ideal for further accommodation, full electrics on separate circuit, water connected, connected to septic tank, subject to the necessary planning regulations.part-converted barnalmost completed up to 2nd fix with own separate electrics and own septic tank, water connected. accommodation consistins of:front entrancegiving access to:sitting room 6.35m(20'10'') x 5.54m(18'2'')overlooked by the galleried landing, with part exposed stone walls, french windows out to garden area.kitchen / dining room 5.44m(17'10'') x 4.04m(13'3'')with exposed stone walling (kitchen not fitted), utility room off.bedroom 1 4.55m(14'11'') x 3.86m(12'8'')with exposed stone walls, ensuite bathroom (not fitted).first floorstaircase not yet fitted, landing giving access to:bedroom 2 4.50m(14'9'') x 3.81m(12'6'')with exposed stone walling.bedroom 3 5.61m(18'5'') x 4.09m(13'5'')again with exposed stone walling, en suite bathroom (not fitted).bathroomnot fitted, accessed from galleried landing.loft spacethe loft space has been boarded and accommodation trusses used which gives the potential for a loft conversion providing a further 2 bedrooms. the roof has been fitted with removable slates ready for velux roof windows.barn / cow shed. 14.66m(48'1'') x 4.72m(15'6'')currently divided into two loose boxes, hay barn and tack area. own electricity supply and septic tank.former cottagederelict, basically 3 walls and a fireplace (which could be restored subject to planning)workshop / garden storewith log store.static caravanwith 3 bedrooms, lpg gas connection for cooking and hot water. electricity connected, water and connected to septic tank. there is also a shed which has connection for washing machine and a storage area.externallythe property is approached from a quiet country road by a tree-lined drive. the drive divides into two half-way down - one entrance giving the barn conversion its own entrance and the other entrance track leading to the house. to the side of the entrance lane is a fully enclosed pen area which could be used for a variety of purposes. there are spacious grounds ...
# 86   a freehold detached four bedroom centrally heated dormer bungalow with two reception rooms, bathroom, and garden front and rear. eer 39descriptionref: lap02195bow street ceredigiona popular village on the a487 bus route, 4 miles north of the university townand seaside resort of aberystwythfor sale by private treatya freehold detached four bedroom centrally heated dormer bungalowwith two reception rooms, bathroom,garden front and rear.known ashendre gwyndiroffers in the region of will be considered.situation & locationbow street provides excellent village amenities including supermarket, post office, butcher, primary school and community hall. a regular bus service operates to and from aberystwyth, whilst the coast of borth and ynyslas is within 3 miles.the property is found within the village on the right hand side, being the second property when travelling from aberystwyth in a northerly direction.constructionthe property was built in circa 1930's of traditional brick walls with rendered external elevations. the main walls support a pitched roof laid with natural slate.accommodationthis dormer style bungalow provides the following accommodation:-ground floorrecess storm porch with half panelled glazed door to:-hall with panelled radiator, feature spiral staircase to first floor and doors to:-front bedroom (12' x 9') (3.66m x 2.74m) with window to front and side, panelled radiator, two twinpower points, feature fireplace.main bedroom (12'8' x 9'11') (3.86m x 3.02m) with window to side, old cast iron fireplace, doublepanelled radiator, power points, access to dressing room (potential en-suite facility)bathroom with pedestal wash hand basin (h&c), panelled bath with shower adaptor, low flushw.c., extractor fan, double panelled radiator.separate toilet with high flush w.c., wash hand basin (h&c).lounge (19' x 11') (5.79m x 3.35m) with window to front and rear, two double panelled radiators,open fireplace with tiled hearth and back with painted slate surround, three twin power points,television point.dining room (12' x 11'6') (3.66m x 3.51m) with window to front, double panelled radiator, two twinpower points, alcove cupboard with panelled radiator.kitchen (11'6' x 7'6') (3.51m x 2.29m) with single drainer stainless steel sink (h&c), wall mounted'worcester' gas fire which heats hot water and central heating, two twin power points, cookercontrol with power point, electric meter and consumer unit, door to outside.first floor approached by spiral staircase to central landing area with doors to:-bedroom (10' x 8'8') (3.05m x 2.64m) with panelled radiator, velux roof window, twin power point.other bedroom (10'10' x 10'2') (3.30m x 3.10m) with velux roof window, two twin power points,access hatch to eaves storage space.outsideto front, vehicular driveway, garden mainly laid to lawn.to rear, patio seating area, lawned garden. static caravan being ideal store.energy performance certificate graphcouncil tax band ' d '.generalthe bungalow occupies a village location within walking distance to local amenities. the property can be refurbished to individual taste.for further details applylloyd, herbert & joneswho will be pleased to arrange viewing.money laundering regulationsthe successful purchaser will be required to produce adequate identification to prove their identity within the terms of the money laundering regulations. appropriate examples include: passport/photo driving licence and a recent utility bill.whilst we endeavour to make our sales details accurate and reliable they should not be relied on as statements or representations of fact and do not constitute any part of an offer or contract. the seller does not make or give nor do we or our employees have the authority to make or give any representation or warranty in relation to the property. please contact the office before viewing the property. if there is any point which is of particular importance to you we will be pleased to check the information for you and to confirm th ...
# 425  an ideal opportunity to acquire this modern two bedroom detached mobile home situated within the shirkoak park area on the outskirts of the popular village of woodchurch.the property is available with no onward chain and is fully furnished with a fitted kitchen to include dishwasher and washing machine.further benefits include upvc double glazing, gas fired central heating and a block-paved driveway.lounge/diner: 3.73m x 2.67m & 2.34m x 2.6m double glazed bay window to side. two radiators. double glazed window to front. electric fireplace. coved and textured ceiling. furnished. kitchen: 3.73m x 2.6m obscure double glazed window to side. double glazed window to side. stainless steel sink with drainer unit. wall and base units with worksurfaces over. built-in gas hob with extactor over. built-in electric oven. radiator. built-in dishwasher. integral washing machine. boiler. fridge/freezer. inner hallway: 2.7m x 0.91m built-in cupboard. external: 12.2m x 15.24m outside tap. paved patio. concrete pre-fab shed. block-paved driveway with parking for three vehicles. entrance: double glazed door and side screen to: bedroom two: 2.74m x 2.6m double glazed window to side. radiator. fitted double wardrobe. bedroom one: 3.4m x 2.6m to 1.65m double glazed window to rear. radiator. fitted double wardrobe. bathroom: obscure double glazed window to rear. panelled bath with shower over. low level wc. wash hand basin.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
#
# [90 rows x 3 columns]

# %%
# concatenated the predictions with the original udbc zoopla dataset
result = pd.concat([newdf,Pred_output_dataframe],axis=1)

# %%
result.to_csv('predicted_caravan_A.csv')

# %% [markdown]
# ## TO DO: experimental features
# ### trying unupervised clustering of topics with nonNegative matrix factorization method

# %%
def print_top_words(model, feature_names, n_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print("Topic #%d:" % topic_idx)
        print(" ".join([feature_names[i]
                        for i in topic.argsort()[:-n_top_words - 1:-1]]))
    print()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation

print("Extracting tf-idf features for NMF...")

tfidf_vectorizer = TfidfVectorizer(max_df=0.95, min_df=2,
                                   max_features=10000,
                                   stop_words='english')

tfidf = tfidf_vectorizer.fit_transform(X)


nmf = NMF(n_components=10 ,random_state=1,
          alpha=.1, l1_ratio=.5).fit(tfidf)
# Out:
# Extracting tf-idf features for NMF...

# %%
print("Topics in NMF model:")
tfidf_feature_names = tfidf_vectorizer.get_feature_names()
print_top_words(nmf, tfidf_feature_names, 10)
# Out:
# Topics in NMF model:
# Topic #0:
# glazed double window radiator upvc rear aspect door wall ceiling
# Topic #1:
# holiday letting home let need park want like enjoy complete
# Topic #2:
# apartment large bedroom floor property furnished modern london reception station
# Topic #3:
# glazed connells buyers double window property measurements radiator park advised
# Topic #4:
# kemp littlesea caravan pleased holiday weymouth sale offer park bedroom
# Topic #5:
# room park property home bedroom bedrooms detached double living garage
# Topic #6:
# website material make party available aspect owners use consent redistribute
# Topic #7:
# general particulars property accordingly prospective max make facing buyers fact
# Topic #8:
# wells north park builth wales mid town miles llandrindod welsh
# Topic #9:
# landlord openrent tenancy rent pay fees reference referencing tenants available

# %% [markdown]
# ### This is a very simple pipeline using the OneHotEncoding transformation before the classifier

# %%
OHEmodel = Pipeline([
        ('vectorizer', CountVectorizer()),
        ('onehot', Binarizer()),
        ('classifier', LogisticRegression()),
])

# %%
OHEmodel.fit(train_X,train_y)
# Out:
# Pipeline(steps=[('vectorizer', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#        ...ty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False))])

# %%
scores = cross_val_score(OHEmodel, X, y, cv=5)

print("------------------- pipeline -----------------------")
print (scores)
print (np.mean(scores))
# Out:
# ------------------- pipeline -----------------------
# [ 0.94007491  0.95131086  0.86516854  0.99250936  0.81203008]
# 0.91221874912

# %%
print(show_most_informative_features(OHEmodel))
# Out:
# 2.3532              park                -0.7702             floor
# 1.9429              home                -0.6739             house
# 1.4821                to                -0.6213             first
# 0.9235        themselves                -0.5705         apartment
# 0.7834              over                -0.5662            stairs
# 0.7777              more                -0.5469              flat
# 0.7069               are                -0.5311         available
# 0.6759           caravan                -0.4990           landing
# 0.5030              side                -0.4819             three
# 0.4858           holiday                -0.3738              rear
# 0.4674             about                -0.3676           terrace
# 0.4635              plot                -0.3673            street
# 0.4631         wardrobes                -0.3586             links
# 0.4600              sale                -0.3513         transport
# 0.4434            mobile                -0.3403            second
